# %% [markdown]
# <a href="https://colab.research.google.com/github/shahidfarhan22/ML_models/blob/main/News_Category.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
# files.upload()
# df=pd.read_json(r"C:\Users\pc\Downloads\archive (8)\News_Category_Dataset_v3.json")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_json('/content/drive/MyDrive/Projects/News_Category_Dataset_v3.json',lines=True)
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
df.shape
# Out:
# (209527, 6)

# %%
df['headline'][0]
# Out:
# 'Over 4 Million Americans Roll Up Sleeves For Omicron-Targeted COVID Boosters'

# %%
df['short_description'][0]
# Out:
# 'Health experts said it is too early to predict whether demand would match up with the 171 million doses of the new boosters the U.S. ordered for the fall.'

# %%
df=pd.DataFrame(df,columns=['headline','category'])
df.head(10)
# Out:
#                                             headline        category
# 0  Over 4 Million Americans Roll Up Sleeves For O...       U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...       U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...          COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...       PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...       U.S. NEWS
# 5  Cleaner Was Dead In Belk Bathroom For 4 Days B...       U.S. NEWS
# 6  Reporter Gets Adorable Surprise From Her Boyfr...       U.S. NEWS
# 7  Puerto Ricans Desperate For Water After Hurric...      WORLD NEWS
# 8  How A New Documentary Captures The Complexity ...  CULTURE & ARTS
# 9  Biden At UN To Call Russian War An Affront To ...      WORLD NEWS

# %%
df.category.value_counts()
# Out:
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# ...

# %%
category_list=[]

for category in df['category']:
  if category not in category_list:
    category_list.append(category)
  else:
    continue
# category_list

# %% [markdown]
# Balancing the dataset

# %%
min_samples=1014
balanced_category=[]



df_DIVORCE=df[df.category =='DIVORCE'].sample(min_samples,random_state=22)
df_POLITICS=df[df.category =='POLITICS'].sample(min_samples,random_state=22)
df_WELLNESS=df[df.category =='WELLNESS'].sample(min_samples,random_state=22)
df_ENTERTAINMENT=df[df.category =='ENTERTAINMENT'].sample(min_samples,random_state=22)
df_TRAVEL=df[df.category =='TRAVEL'].sample(min_samples,random_state=22)
df_STYLE_BEAUTY=df[df.category =='STYLE & BEAUTY'].sample(min_samples,random_state=22)
df_PARENTING=df[df.category =='PARENTING'].sample(min_samples,random_state=22)
df_HEALTHY_LIVING=df[df.category =='HEALTHY LIVING'].sample(min_samples,random_state=22)
df_QUEER_VOICES=df[df.category =='QUEER VOICES'].sample(min_samples,random_state=22)
df_FOOD_DRINK=df[df.category =='FOOD & DRINK'].sample(min_samples,random_state=22)
df_BUSINESS=df[df.category =='BUSINESS'].sample(min_samples,random_state=22)
df_COMEDY=df[df.category =='COMEDY'].sample(min_samples,random_state=22)
df_SPORTS=df[df.category =='SPORTS'].sample(min_samples,random_state=22)
df_BLACK_VOICES=df[df.category =='BLACK VOICES'].sample(min_samples,random_state=22)
df_WOMEN=df[df.category =='WOMEN'].sample(min_samples,random_state=22)
df_CRIME=df[df.category =='CRIME'].sample(min_samples,random_state=22)
df_IMPACT=df[df.category =='IMPACT'].sample(min_samples,random_state=22)
df_WORLD_NEWS=df[df.category =='WORLD NEWS'].sample(min_samples,random_state=22)
df_MEDIA=df[df.category =='MEDIA'].sample(min_samples,random_state=22)
df_WEIRD_NEWS=df[df.category =='WEIRD NEWS'].sample(min_samples,random_state=22)
df_GREEN=df[df.category =='GREEN'].sample(min_samples,random_state=22)
df_WORLDPOST=df[df.category =='WORLDPOST'].sample(min_samples,random_state=22)
df_RELIGION=df[df.category =='RELIGION'].sample(min_samples,random_state=22)
df_STYLE=df[df.category =='STYLE'].sample(min_samples,random_state=22)
df_SCIENCE=df[df.category =='SCIENCE'].sample(min_samples,random_state=22)
df_TECH=df[df.category =='TECH'].sample(min_samples,random_state=22)
df_TASTE=df[df.category =='TASTE'].sample(min_samples,random_state=22)
df_MONEY=df[df.category =='MONEY'].sample(min_samples,random_state=22)
df_ARTS=df[df.category =='ARTS'].sample(min_samples,random_state=22)
df_ENVIRONMENT=df[df.category =='ENVIRONMENT'].sample(min_samples,random_state=22)
df_FIFTY=df[df.category =='FIFTY'].sample(min_samples,random_state=22)
df_GOOD_NEWS=df[df.category =='GOOD NEWS'].sample(min_samples,random_state=22)
df_US_NEWS=df[df.category =='U.S. NEWS'].sample(min_samples,random_state=22)
df_ARTS_CULTURE=df[df.category =='ARTS & CULTURE'].sample(min_samples,random_state=22)
df_COLLEGE=df[df.category =='COLLEGE'].sample(min_samples,random_state=22)
df_LATINO_VOICES=df[df.category =='LATINO VOICES'].sample(min_samples,random_state=22)
df_CULTURE_ARTS=df[df.category =='CULTURE & ARTS'].sample(min_samples,random_state=22)
df_EDUCATION=df[df.category =='EDUCATION'].sample(min_samples,random_state=22)












# for cat in category_list:
#   # a=='df_'+cat
#   balanced_category.append(cat)
#   cat= df[df.category ==str(cat)].sample(min_samples,random_state=22)
#   # df_balanced =pd.concat([cat],axis=0,)
#   # balanced_category.append(cat)
#   print(cat)

# # balanced_cat=','.join(balanced_category)
# balanced_category
# # df_balanced.head()

# %%
df_balanced=pd.concat([df_EDUCATION,df_CULTURE_ARTS,df_LATINO_VOICES,df_COLLEGE,df_ARTS_CULTURE,df_US_NEWS,df_GOOD_NEWS,df_FIFTY,df_ENVIRONMENT,
                       df_ARTS,df_MONEY,df_TASTE,df_TECH,df_SCIENCE,df_STYLE,df_RELIGION,df_WORLDPOST,df_GREEN,df_WEIRD_NEWS,df_MEDIA,df_WORLD_NEWS,df_IMPACT,
                       df_CRIME,df_WOMEN,df_BLACK_VOICES,df_SPORTS,df_COMEDY,df_BUSINESS,df_FOOD_DRINK,df_QUEER_VOICES,df_HEALTHY_LIVING,df_PARENTING,df_STYLE_BEAUTY,df_TRAVEL,
                       df_ENTERTAINMENT,df_WELLNESS,df_POLITICS,df_DIVORCE],axis=0)

df_balanced.category.value_counts()






# lst=pd.Series(balanced_category)
# # lst
# df_balanced=pd.concat(data=lst,axis=0)
# # df_balanced.category.value_counts()
# Out:
# EDUCATION         1014
# FOOD & DRINK      1014
# IMPACT            1014
# CRIME             1014
# WOMEN             1014
# BLACK VOICES      1014
# SPORTS            1014
# COMEDY            1014
# BUSINESS          1014
# QUEER VOICES      1014
# CULTURE & ARTS    1014
# HEALTHY LIVING    1014
# PARENTING         1014
# STYLE & BEAUTY    1014
# TRAVEL            1014
# ENTERTAINMENT     1014
# WELLNESS          1014
# POLITICS          1014
# WORLD NEWS        1014
# MEDIA             1014
# WEIRD NEWS        1014
# GREEN             1014
# LATINO VOICES     1014
# COLLEGE           1014
# ARTS & CULTURE    1014
# U.S. NEWS         1014
# GOOD NEWS         1014
# FIFTY             1014
# ENVIRONMENT       1014
# ARTS              1014
# MONEY             1014
# TASTE             1014
# TECH              1014
# SCIENCE           1014
# STYLE             1014
# RELIGION          1014
# WORLDPOST         1014
# DIVORCE           1014
# Name: category, dtype: int64

# %%
df_balanced.head(1015)
# Out:
#                                                  headline        category
# 122729  Jim Jeffords: A Founder of the Movement to Exp...       EDUCATION
# 27721   As Teachers, We Are Responsible For James Alex...       EDUCATION
# 23136         C’mon, Matt Damon. You’re Better Than This.       EDUCATION
# 101606  To Meet New Student Standards, We Must Support...       EDUCATION
# 67507        Giving Teenagers Weapons is NEVER a Solution       EDUCATION
# ...                                                   ...             ...
# 130917  Home Ec 2.0: How Cooking Could Save Our Lives ...       EDUCATION
# 119813  Shakira and Massachusetts Mayor Agree: Learnin...       EDUCATION
# 27609   If State Takeover Of New Orleans Schools Worke...       EDUCATION
# 125558                 Mr. Minkel Goes to the White House       EDUCATION
# 139246  Corporations, Once Happy Buyers of Art, Are No...  CULTURE & ARTS
#
# [1015 rows x 2 columns]

# %% [markdown]
# Let's Train the model

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

l=LabelEncoder()
df_balanced['category_num']=l.fit_transform(df_balanced['category'])
df_balanced.head(1016)
# df_balanced.category_num.value_counts()
# Out:
#                                                  headline        category  \
# 122729  Jim Jeffords: A Founder of the Movement to Exp...       EDUCATION
# 27721   As Teachers, We Are Responsible For James Alex...       EDUCATION
# 23136         C’mon, Matt Damon. You’re Better Than This.       EDUCATION
# 101606  To Meet New Student Standards, We Must Support...       EDUCATION
# 67507        Giving Teenagers Weapons is NEVER a Solution       EDUCATION
# ...                                                   ...             ...
# 119813  Shakira and Massachusetts Mayor Agree: Learnin...       EDUCATION
# 27609   If State Takeover Of New Orleans Schools Worke...       EDUCATION
# 125558                 Mr. Minkel Goes to the White House       EDUCATION
# 139246  Corporations, Once Happy Buyers of Art, Are No...  CULTURE & ARTS
# 153814  Artist Creates Perfect Illustrations For Roald...  CULTURE & ARTS
#
#         category_num
# 122729             9
# 27721              9
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df_balanced.headline,df_balanced.category_num,test_size=0.2,random_state=2,stratify=df_balanced.category_num)

# %% [markdown]
# stratify is to used to make sure both the train and test set have equal number of category_num rows which is showm below

# %%
print(X_train.shape)
X_train.head()
# Out:
# (30825,)
# 67354     Nervous Flyer Screwed By Pals Who Secretly Pac...
# 40649     Joan Didion’s New Book Explores The Bubble Of ...
# 116771    Toygodd Attends Exact Science Gallery's Grand ...
# 121090               How We Do It: Success in the Classroom
# 48823     Kerry Washington Shines On The Red Carpet, 2 M...
# Name: headline, dtype: object

# %%
y_test.value_counts()
# Out:
# 8     203
# 27    203
# 5     203
# 4     203
# 37    203
# 11    203
# 2     203
# 22    203
# 3     203
# 19    203
# 24    203
# 14    203
# 35    203
# 1     203
# 6     203
# 33    203
# 10    203
# 36    203
# 28    203
# 17    203
# 29    203
# 7     203
# 15    203
# 34    203
# 23    203
# 25    203
# 26    203
# 21    203
# 20    203
# 32    203
# 18    203
# 30    202
# 12    202
# 9     202
# 0     202
# 13    202
# 16    202
# 31    202
# Name: category_num, dtype: int64

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer


clf=Pipeline([
    ('vectorizer_bow',CountVectorizer(ngram_range=(1,3))),
    ('Multi_NB',MultinomialNB())
])

clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.01      0.01       296
#            1       1.00      0.00      0.01       287
#            2       0.83      0.05      0.09       943
#            3       0.81      0.09      0.16      1206
#            4       0.00      0.00      0.00       237
#            5       0.82      0.09      0.17      1072
#            6       0.69      0.21      0.32       695
#            7       0.83      0.07      0.13       211
#            8       0.96      0.22      0.36       682
#            9       0.86      0.03      0.05       223
#           10       0.42      0.77      0.54      3378
#           11       1.00      0.07      0.13       297
#           12       0.00      0.00      0.00       266
#           13       0.73      0.49      0.59      1241
#           14       0.00      0.00      0.00       280
#           15       0.75      0.02      0.03       520
# ...

# %%
X_test[:5]
# Out:
# 66186                           Take My Religion ... Please
# 186879    New York Fashion Week: Blue Eyeshadow At Jerem...
# 100042            5 Ways To Make Sense Of Your Running Data
# 73390     Ruh-Roh! Runaway 'Mystery Machine' Takes Polic...
# 64187     Elizabeth Warren Slams Trump For Being 'A Frau...
# Name: headline, dtype: object

# %%
y_test[:5]
# Out:
# 66186     12
# 186879    30
# 100042    16
# 73390      6
# 64187     24
# Name: category_num, dtype: int64

# %%
y_pred[:5]
# Out:
# array([38, 30, 38, 24, 24])

# %%
df_balanced['category']
# Out:
# 122729    EDUCATION
# 27721     EDUCATION
# 23136     EDUCATION
# 101606    EDUCATION
# 67507     EDUCATION
#             ...
# 138639      DIVORCE
# 180443      DIVORCE
# 155630      DIVORCE
# 146275      DIVORCE
# 166027      DIVORCE
# Name: category, Length: 38532, dtype: object

# %%
import spacy
nlp=spacy.load('en_core_web_sm')
def preprocess(text):
  doc=nlp(text)

  filtered_tokens=[]
  for token in doc:
    if token.is_stop or token.is_punct:
      continue
    filtered_tokens.append(token.lemma_)


  return " ".join(filtered_tokens)

# %%
df_balanced['preprocessed_txt']=df_balanced.headline.apply(preprocess)

# %%
df_balanced.head(10000)
# Out:
#                                                  headline   category  \
# 122729  Jim Jeffords: A Founder of the Movement to Exp...  EDUCATION
# 27721   As Teachers, We Are Responsible For James Alex...  EDUCATION
# 23136         C’mon, Matt Damon. You’re Better Than This.  EDUCATION
# 101606  To Meet New Student Standards, We Must Support...  EDUCATION
# 67507        Giving Teenagers Weapons is NEVER a Solution  EDUCATION
# ...                                                   ...        ...
# 124846    Birds of a Feather: Three New York "Swan Lakes"       ARTS
# 96077   This Woman Photographed Herself Every Time She...       ARTS
# 103484  First Nighter: "Don Carlo" at the Met Is Grand...       ARTS
# 120380  This Is How You Visualize The Heartbeat Of A City       ARTS
# 98181                                  The Art of Keatley       ARTS
#
#         category_num                                   preprocessed_txt
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df_balanced.preprocessed_txt,df_balanced.category_num,test_size=0.2,random_state=2,stratify=df_balanced.category_num)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer


clf=Pipeline([
    ('vectorizer_bow',CountVectorizer()),
    ('Multi_NB',MultinomialNB())
])

clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.26      0.30       202
#            1       0.38      0.36      0.37       203
#            2       0.33      0.31      0.32       203
#            3       0.40      0.28      0.33       203
#            4       0.57      0.57      0.57       203
#            5       0.47      0.42      0.45       203
#            6       0.40      0.68      0.50       203
#            7       0.49      0.46      0.48       203
#            8       0.66      0.70      0.68       203
#            9       0.51      0.54      0.52       202
#           10       0.38      0.39      0.39       203
#           11       0.40      0.40      0.40       203
#           12       0.32      0.27      0.29       202
#           13       0.48      0.46      0.47       202
#           14       0.34      0.48      0.40       203
#           15       0.37      0.31      0.34       203
# ...

# %%
df=pd.read_json('/content/drive/MyDrive/Projects/News_Category_Dataset_v3.json',lines=True)
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
df.shape
# Out:
# (209527, 6)

# %%
df=pd.DataFrame(df,columns=['headline','category'])
df.head(10)
# Out:
#                                             headline        category
# 0  Over 4 Million Americans Roll Up Sleeves For O...       U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...       U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...          COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...       PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...       U.S. NEWS
# 5  Cleaner Was Dead In Belk Bathroom For 4 Days B...       U.S. NEWS
# 6  Reporter Gets Adorable Surprise From Her Boyfr...       U.S. NEWS
# 7  Puerto Ricans Desperate For Water After Hurric...      WORLD NEWS
# 8  How A New Documentary Captures The Complexity ...  CULTURE & ARTS
# 9  Biden At UN To Call Russian War An Affront To ...      WORLD NEWS

# %%
df.category.value_counts()
# Out:
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# ...

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

l=LabelEncoder()
df['category_num']=l.fit_transform(df['category'])
df.head(1016)
# df_balanced.category_num.value_counts()
# Out:
#                                                headline    category  \
# 0     Over 4 Million Americans Roll Up Sleeves For O...   U.S. NEWS
# 1     American Airlines Flyer Charged, Banned For Li...   U.S. NEWS
# 2     23 Of The Funniest Tweets About Cats And Dogs ...      COMEDY
# 3     The Funniest Tweets From Parents This Week (Se...   PARENTING
# 4     Woman Who Called Cops On Black Bird-Watcher Lo...   U.S. NEWS
# ...                                                 ...         ...
# 1011  No Charges Against Chicago Police Officers In ...   U.S. NEWS
# 1012  UN Says Women Pay Highest Price In Conflict, N...  WORLD NEWS
# 1013  UN Chief: Ukraine War Hitting Poor Nations Rel...  WORLD NEWS
# 1014  UC Berkeley Can Enroll Thousands More Students...    POLITICS
# 1015  U.S. Astronaut To Return On Russian Capsule De...   U.S. NEWS
#
#       category_num
# 0               35
# 1               35
# 2                5
# 3               22
# 4               35
# ...            ...
# ...

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df.headline,df.category_num,test_size=0.2,random_state=2)#,stratify=df_balanced.category_num)

# %%
print(X_train.shape)
X_train.head()
# Out:
# (167621,)
# 184165    Peter Jackson & Stephen Colbert: Director Addr...
# 116725    Halloween: The Season for Culturally-Insensiti...
# 128368                             A Year Out of the Closet
# 178742    Louise Bourgeois's Birthday: Celebrating The F...
# 73337           Bernie Sanders Wins Maine Democratic Caucus
# Name: headline, dtype: object

# %%
y_test.value_counts()
# Out:
# 24    7054
# 38    3581
# 10    3378
# 30    2016
# 34    1975
# 22    1756
# 16    1373
# 13    1241
# 25    1238
# 3     1206
# 5     1072
# 28     988
# 2      943
# 17     851
# 23     808
# 36     748
# 33     742
# 18     735
# 40     730
# 39     722
# 6      695
# 8      682
# 37     557
# 20     555
# 26     528
# 15     520
# 41     500
# 31     448
# 32     447
# 29     446
# 27     418
# 21     355
# 11     297
# 0      296
# 1      287
# 14     280
# 35     276
# 12     266
# 4      237
# 19     225
# 9      223
# 7      211
# Name: category_num, dtype: int64

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer


clf=Pipeline([
    ('vectorizer_bow',CountVectorizer()),
    ('Multi_NB',MultinomialNB())
])

clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       296
#            1       1.00      0.00      0.01       287
#            2       0.78      0.05      0.09       943
#            3       0.80      0.10      0.18      1206
#            4       0.00      0.00      0.00       237
#            5       0.81      0.09      0.17      1072
#            6       0.65      0.27      0.38       695
#            7       1.00      0.05      0.10       211
#            8       0.95      0.25      0.39       682
#            9       0.50      0.00      0.01       223
#           10       0.41      0.79      0.54      3378
#           11       1.00      0.05      0.09       297
#           12       0.00      0.00      0.00       266
#           13       0.72      0.50      0.59      1241
#           14       0.00      0.00      0.00       280
#           15       0.62      0.02      0.04       520
# ...

# %%
df['preprocessed_txt']=df.headline.apply(preprocess)

# %%
df.shape
# Out:
# (209527, 4)

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(df.preprocessed_txt,df.category_num,test_size=0.2,random_state=2
                                                 )

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer


clf=Pipeline([
    ('vectorizer_bow',CountVectorizer()),
    ('Multi_NB',MultinomialNB())
])

clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.03      0.05       296
#            1       0.73      0.03      0.05       287
#            2       0.58      0.21      0.31       943
#            3       0.49      0.29      0.36      1206
#            4       0.67      0.03      0.05       237
#            5       0.59      0.27      0.37      1072
#            6       0.51      0.56      0.53       695
#            7       0.77      0.08      0.15       211
#            8       0.85      0.51      0.64       682
#            9       1.00      0.03      0.06       223
#           10       0.45      0.78      0.57      3378
#           11       0.77      0.07      0.12       297
#           12       0.50      0.01      0.01       266
#           13       0.62      0.70      0.66      1241
#           14       0.45      0.04      0.07       280
#           15       0.49      0.13      0.20       520
# ...
